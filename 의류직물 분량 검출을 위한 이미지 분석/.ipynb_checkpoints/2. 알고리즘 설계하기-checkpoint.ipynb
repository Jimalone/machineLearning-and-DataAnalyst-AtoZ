# %% [markdown]
# # 2. 알고리즘 설계하기
#
# ## 학습 목표
# 1. 데이터와 프로그램을 만드는 순서
# 2. 어떻게 모듈화를 하느냐
# 3. 데이터셋을 어떻게 빌드하고 학습할 것이냐
# 4. 학습 알고리즘은 어떤 네트워크로 학습 할 것이냐에 대한
# 방향을 잡는다.

# %% [markdown]
# 스크린샷 2020-03-01 오후 8.08.29![image.png](attachment:image.png)

# %% [markdown]
# 스크린샷 2020-03-01 오후 8.11.21![image.png](attachment:image.png)

# %% [markdown]
# 그래서 여기서는 테스트용 프로그램까지만 구형을 해 보고
# 정식 프로그램, 학습 프로그램 처럼 UI가 중요한 프로그램은
# '파이큐티 파이사이드 티키인터'라던지 파이썬 기반의 UI프로그램을 참고해서 직접 만들어보는 것도 좋을 듯 하다.

# %% [markdown]
# # 본격적인 데이터 분석의 시간.
# > 이진 분류 문제가 어떤 것들을 분석 할 수 있는 능력이 필요한지 고민해 보아야 한다.
# > 정상과 불량을 비교하며 불량의 특징을 파악하고,
# >> 데이터 증강 방법과
# >>> 유사한 형태의 defect가 다양한 방향과 위치에서 나타난다.
# >> 학습할 아키텍쳐, 모델을 정해야 한다.
# >>> multi-Scale Feature에 대한 고려가 필요하다. 작은 Defect도 있고, 큰 Defect도 있기 때문
# 스크린샷 2020-03-01 오후 8.17.10![image.png](attachment:image.png)
# >>> -inception module 이 multi-Scale Feature에 대한 고려가 있다고 볼 수 있다.

# %% [markdown]
# 결과적으로,
# 스크린샷 2020-03-01 오후 8.19.50![image.png](attachment:image.png)
