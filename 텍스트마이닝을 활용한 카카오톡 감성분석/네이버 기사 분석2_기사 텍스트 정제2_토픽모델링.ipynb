# %% [markdown]
# # 네이버 기사 분석2 -기사 텍스트 정제
# ## 토픽모델링

# %% [markdown]
# ## 1. 토픽모델링이란
#
# ### 1) 토픽 모델링의 정의
#    - 문서에서 토픽(키워드)을 찾는 과정
#    - 문서(문장)을 구성하는 단어조합으로부터 k개의 단어 묶음을 찾는 과정
#    -  **베이지안 확률모델** 이며, 토픽 모델링의 결과로 각 단어가 각 토픽에 속할 확률이 나옴
#
#    #### 알아야 하는 것
#            - 베이지안 통계 모델 특히 베이지안 통계모델에서 어떻게 확률적으로 모델을 추론하는지에 대해서 알고 있어야 함
#            - document term matrix라고 불리는 문서를 표현하는 방법
#                1. 문서 단어 행렬(Document-Term Matrix, DTM)의 표기법
#                     : 문서 단어 행렬(Document-Term Matrix, DTM)이란 다수의 문서에서 등장하는 각 단어들의 빈도를 행렬로 표현한 것을 말합니다. 쉽게 생각하면 각 문서에 대한 BoW를 하나의 행렬로 만든 것으로 생각할 수 있으며, BoW와 다른 표현 방법이 아니라 BoW 표현을 다수의 문서에 대해서 행렬로 표현하고 부르는 용어입니다.
#            - 확률계산
#            - 수리 통계적 내용. 기초통계를 엄밀히 증명하는 것

# %% [markdown]
# ### 2) 토픽 모델링의 역사
# ####  1. LSI (Latent Semantic Indexing):
# - 문서-단어 행렬(document-term matrix) : 행)단어, 열)문서 로 쓰면, column하나가 문서하나가 된다.
# - 문서-단어 행렬에 SVD
# - SVD에 의해 저차원으로 변환된 벡터가 semantic을 표현
#
# #### 2. pLSI (probablility Latent Semantic Analysis)
# - 문서-단어 행렬은 그대로 유지하면서
# - 문서 별 빈도가 아닌, 등장 확률을 기반으로 표현
#
# #### 3 LDA ( Latent Dirichlet Allocation)
# - Dirichlet 확률분포 사용
#
# #### 4. ATM, DTM, CTM, RTM...

# %% [markdown]
# ### 3) 잠재 디리클레 할당 (Latent Dirichlet Allocation, LDA)
# 출처 : David M. Blei, Andrew Y. Ng, Michael I. Jordan, Latent Dirichlet Allocation, Journal of Machine Learning Research, 2003
#
# #### LDA의 모델 가정
# - 각 문서엔 여러 개의 토픽이 포함 될 수 있다. : pLSI가 하나의 문서에 여러 개의 토픽이 들어가는 경우에는 부적절해서 LDA에선 이런 가정을 하여 확장.
# - 각 토픽에는 여러 개의 단어가 포함 될 수 있다.
# - 문서에는 존재하는 모든 단어는 반드시 어떤 토픽에 포함된다.
# - 사람이 글을 쓰는 과정을 생성 모델(Generative Model)로 정의한다.
#
# #### LDA의 모델 과정
# - 1. 문서들에 사용할 토픽을 고른다. (k개의 토픽)
# - 2. 토픽 중 하나의 토픽을 고른다.
# - 3. 그 토픽에 포함된 단어 중에 하나를 고른다.
# - 4. 단어를 문서에 추가한다 (글을 쓴다. )
# - 5. 2번 과정부터 계속 반복한다.

# %% [markdown]
# #### LDA를 하는 과정 - 어려워요.. 모르겠어요..공부 더 할게요..

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.41.47.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.41.47.png)

# %% [markdown]
# K개의토픽에대한다항분포를추정하기위해
#
# 디리클레분포를사용하는것에서유래
#
# • 단어가 K개의 토픽에 속하는 확률분포를 알 수 없으므로 베이지안확률 모델을 사용하여 분포를 추정
#
# • 비슷한 예제:가위바위보
#
# 1)두 명이 가위바위보를 하는데, 상대방이 가위,바위,보를 얼마나 냈는지를 알고있음(사전분포)
#
# e.g. (가위,바위,보) = (100, 70, 30)
#
# 2)알게된 정보를 통해 다음에 나올 수를 예측
#
# e.g. X ~ Dir(100, 70, 30)
#
# 3) 이때 각 시행이 단어를 토픽에서 임의로 뽑는 것과 같고, 그 단어가 어떤 토픽에 할당 되는 과정을 계속 반복하여 확률분포가 수렴하면 종료

# %% [markdown]
# #### LDA의 예시

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.49.19.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-15%20%E1%84%8B%E1%85%A9%E1%84%92%E1%85%AE%203.49.19.png)

# %% [markdown]
# AP통신기사 중에 하나를 LDA한결과
# • 4개의 토픽(K=4)으로 토픽모델링을 진행하고, 확률값이 높은 상위15개의 단어만 출력
# • 토픽의 라벨은 사람이 직접 붙인 것이며, “NEW” 단어의 경우엔 두 개의 토픽에 모두 키워드로 등장
# • 토픽모델링의 결과로 토픽 별로 확률값이 높은 단어들의 목록을 얻는 것을 목적으로 함
