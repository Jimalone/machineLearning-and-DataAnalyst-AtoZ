# %% [markdown]
# # 카카오톡 대화 분석
# ## 사용자별 토픽 분석하기
# ## LDA 에서 Dynamic Topic Model

# %% [markdown]
# : 토픽을 시간 변화로 부터 나눌 순 없을까 라는 생각으로 부터 시작해서
#     시간의 흐름에 따라 토픽 변화를 측정, 분석하는 방법으로 dynamic Topic Model제안
#         LDA + time slice 단위 여러개  = Dynamic Topic Model

# %% [markdown]
# ![%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-19%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.47.55.png](attachment:%E1%84%89%E1%85%B3%E1%84%8F%E1%85%B3%E1%84%85%E1%85%B5%E1%86%AB%E1%84%89%E1%85%A3%E1%86%BA%202019-12-19%20%E1%84%8B%E1%85%A9%E1%84%8C%E1%85%A5%E1%86%AB%2012.47.55.png)
